# %% [markdown]
# # AMIGA-ALMA

# %% [markdown]
# Summary of the ALMA observations for AMIGA with (when needed) upper limits for surface density

# %%
## import
import numpy as np
from math import *
from astropy import units as u 
from astropy import coordinates
from astropy.io import fits
import matplotlib.pyplot as plt
import aplpy

# %matplotlib inline

# %%
def surface_density(ICO, D, inclination):
    "molecular gas surface density for ICO (Jy.km/s) and distance D (Mpc)"
    
    beam=3.14159*6.8*5.5/(4.*log(2.))
    dxdy=1.
    dxypc=(1.*41.6)**2


    mco=1.2e4*ICO*D*dxdy/beam
    h2dens=cos(inclination*pi/180.)*mco/dxypc
    
    return h2dens

# %%
### plot image with contours..
def plot_image(fitsfile, rms , cont_lev, title = ''):

    multp = np.array(cont_lev) # sigma

    lev = rms*multp

    fig = aplpy.FITSFigure(fitsfile)
    fig.set_title(title)
    fig.add_beam()
    fig.beam.set_color('black')
    fig.add_scalebar(1 * u.arcsecond)
    fig.scalebar.set_label('1 arcsec')
    fig.scalebar.set_color("black")
    fig.show_colorscale()
    fig.show_contour(fitsfile, colors='green', levels=lev, alpha=0.5);

# %% [markdown]
# ## CIG 1017

# %% [markdown]
# Not detected in continuum and lines ...
#
#
# Continuum : rms 40 muJy
# Lines : rms 3 mJy

# %%
## Surface density  assuining a 150 km/s line
print surface_density(3*3*150*1e-3, 170, 0.)
# Out:
# 37.5527390141

# %% [markdown]
# # CIG 1019

# %% [markdown]
# Continuum : not detected. rms noise 34 muJy

# %%
plot_image('CIG1019_cont.fits',34e-6, [1,2],'CIG 1019 - Cont.')
# Out:
# INFO: Setting slices=[0, 0] [aplpy.core]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# INFO: Auto-setting vmin to -1.201e-04 [aplpy.core]
# INFO: Auto-setting vmax to  1.224e-04 [aplpy.core]
# INFO: Setting slices=[0, 0] [aplpy.core]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]

# %% [markdown]
# CO(1-0): line strongly detected and spatially resolved.
# Below the moment 0 of CO(1-0)

# %%
plot_image('CIG1019_spw_2_6.image.mom0.fits',1e-1,[50], 'CIG 1019 - CO(1-0) mom. 0')
# Out:
# INFO: Setting slices=[0, 0] [aplpy.core]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# INFO: Auto-setting vmin to  2.713e-02 [aplpy.core]
# INFO: Auto-setting vmax to  6.067e-01 [aplpy.core]
# INFO: Setting slices=[0, 0] [aplpy.core]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]

# %% [markdown]
# ## CIG 1044

# %% [markdown]
# ## CIG 222

# %% [markdown]
# ## CIG 234

# %% [markdown]
# cont. : rms noise 45 muJy. center detected (barely sṕatially resolved): ~380 muJy
# line  : rms noise 2mJy . line well detected and spatially resolved.

# %%
## plot continuum for cig 234
plot_image('CIG234_cont.fits',45e-6, [1,2],'CIG 234 - Cont.')
# Out:
# INFO: Setting slices=[0, 0] [aplpy.core]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# INFO: Auto-setting vmin to -1.432e-04 [aplpy.core]
# INFO: Auto-setting vmax to  1.442e-04 [aplpy.core]
# INFO: Setting slices=[0, 0] [aplpy.core]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]

# %%
## plot CO)1-0) mom. 0  for cig 234
plot_image('CIG234_spw_3_7.mom0.fits',1.5e-0,[50], 'CIG 234 - CO(1-0) Mom. 0')
# Out:
# INFO: Setting slices=[0, 0] [aplpy.core]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# INFO: Auto-setting vmin to -3.064e-01 [aplpy.core]
# INFO: Auto-setting vmax to  4.039e+00 [aplpy.core]
# INFO: Setting slices=[0, 0] [aplpy.core]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]

# %% [markdown]
# ## CIG 268

# %% [markdown]
# ## CIG 494

# %% [markdown]
# ## CIG 501

# %% [markdown]
# ## CIG 55

# %% [markdown]
# ## CIG 664

# %% [markdown]
# ## CIG 676

# %% [markdown]
# ## CIG 82

# %% [markdown]
# ## CIG 86

# %% [markdown]
# ## CIG 88

# %% [markdown]
# ## CIG 930

# %% [markdown]
# ## CIG 931

# %% [markdown]
# ## CIG 935

# %% [markdown]
# ## CIG 956

# %% [markdown]
# ## CIG 976

# %% [markdown]
# ## CIG 992
